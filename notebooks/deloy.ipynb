# %%
# %run setup.py
# %load_ext autoreload
# %autoreload 2

import pandas
import numpy
import matplotlib.pyplot as plt
import seaborn as sns

from utils.data_loader import load_retail_data
from utils.config import *

from src.preprocessing import clean_data, feature_engineering
from src.create_data import create_regression_or_classification_data, create_rfm_data, create_timeseries_data

# %%
# ================ load data
df = load_retail_data()

# ================ preprocessing
df = clean_data(df)
df = feature_engineering(df)

df.columns
# Out:
# Index(['InvoiceNo', 'StockCode', 'Description', 'Quantity', 'InvoiceDate',
#        'UnitPrice', 'CustomerID', 'Country', 'Total', 'Day', 'Month', 'Year',
#        'DayOfWeek', 'Hour', 'Quarter', 'Weekday'],
#       dtype='str')

# %%
df.to_csv(PROCESSED_DATA_DIR / "clean_data.csv", index=False)

# %%
# ================ create data
# ------------------------
create_rfm_data(df)        # for Clustering
# ------------------------
cut_off_date = "2011-09-30"
create_regression_or_classification_data(df, cut_off_date)                      # for Regression
create_regression_or_classification_data(df, cut_off_date, is_classify=True)    # for Classification
# ------------------------
create_timeseries_data(df) # for TimeSeries
# Out:
# Save file in rfm_data.csv
# Save file in regression_data.csv
# Save file in classification_data.csv
# Save file in timeseries_data.csv
#          Date  Weekly_Sales
# 0  2010-12-05    184669.470
# 1  2010-12-12    329108.220
# 2  2010-12-19    215357.040
# 3  2010-12-26     92318.000
# 4  2011-01-02         0.000
# 5  2011-01-09    133429.720
# 6  2011-01-16    192991.950
# 7  2011-01-23    215227.010
# 8  2011-01-30    124534.220
# 9  2011-02-06    125847.360
# 10 2011-02-13    106893.220
# 11 2011-02-20    143354.210
# 12 2011-02-27    148404.190
# 13 2011-03-06    132503.550
# 14 2011-03-13    135076.460
# 15 2011-03-20    161082.620
# 16 2011-03-27    149292.660
# 17 2011-04-03    192398.080
# 18 2011-04-10    134211.440
# 19 2011-04-17    149357.401
# 20 2011-04-24    141530.360
# 21 2011-05-01     86364.580
# 22 2011-05-08    146706.540
# 23 2011-05-15    211708.330
# 24 2011-05-22    215384.190
# 25 2011-05-29    165886.830
# 26 2011-06-05    118357.150
# ...
